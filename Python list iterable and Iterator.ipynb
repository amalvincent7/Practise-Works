# %%
#iterable
lst=[4,8,6,3,10,5]

# %%
for i in lst:
    print (i)
# Out:
# 4
# 8
# 6
# 3
# 10
# 5

# %%
#Converting to Iterator

lst1=iter (lst)

# %%
for i in lst1:
    print(i)
# Out:
# 4
# 8
# 6
# 3
# 10
# 5

# %%
next(lst1)
# Out:
# 8
