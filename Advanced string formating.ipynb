# %%
def name_age(name,age):
    print ("Hello {}, your age is {}".format(name,age))

# %%
name_age("Amal",27)
# Out:
# Hello Amal, your age is 27

# %%
#Assigning placeholders

def name_age(name,age):
    print("Hello {a}, your age is {b}".format(b=age,a=name))

# %%
name_age("Amal",27)
# Out:
# Hello Amal, your age is 27
